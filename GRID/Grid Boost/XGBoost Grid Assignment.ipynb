# %%
import numpy as np
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
param_grid={'n_estimators':[50, 100],
            'random_state':[0],
            'max_depth':[2, 4],
           'learning_rate':[1]}
grid = GridSearchCV(XGBRegressor(), param_grid, refit = True, verbose = 3, n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# GridSearchCV(estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, feature_weights=None,
#                                     gamma=None, grow_policy=None,
#                                     importance_type=None,
#                                     interaction_constraints=None,
#                                     lear...,
#                                     max_cat_threshold=None,
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=-1,
#              param_grid={'learning_rate': [1], 'max_depth': [2, 4],
#                          'n_estimators': [50, 100], 'random_state': [0]},
#              verbose=3)

# %%
re=grid.cv_results_
print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'learning_rate': 1, 'max_depth': 2, 'n_estimators': 50, 'random_state': 0}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.041415      0.001833         0.009481        0.001214
# 1       0.052138      0.002677         0.010081        0.000016
# 2       0.047115      0.007115         0.008666        0.004388
# 3       0.073877      0.004369         0.008060        0.004030
#
#    param_learning_rate  param_max_depth  param_n_estimators  \
# 0                    1                2                  50
# 1                    1                2                 100
# 2                    1                4                  50
# 3                    1                4                 100
#
#    param_random_state                                             params  \
# 0                   0  {'learning_rate': 1, 'max_depth': 2, 'n_estima...
# 1                   0  {'learning_rate': 1, 'max_depth': 2, 'n_estima...
# 2                   0  {'learning_rate': 1, 'max_depth': 4, 'n_estima...
# 3                   0  {'learning_rate': 1, 'max_depth': 4, 'n_estima...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.860225           0.788144           0.872916           0.837859
# 1           0.853398           0.770955           0.861935           0.826440
# 2           0.794807           0.701817           0.797352           0.797380
# 3           0.780714           0.670525           0.778933           0.776052
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.836675         0.839164        0.028961                1
# 1           0.825912         0.827728        0.031803                2
# 2           0.784061         0.775083        0.036961                3
# 3           0.751672         0.751579        0.041871                4

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 35
# BMI: 56
# Children: 3
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 1

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[48568.883]
